# %% [markdown]
# 1,Dataset Loaded from kaggle .

# %% [markdown]
# 2,Online Payments Fraud Detection Dataset

# %%
import pandas as pd
df=pd.read_csv(r"E:\PS_20174392719_1491204439457_log.csv")
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# 1              19384.72  M2044282225            0.00            0.00        0
# 2                  0.00   C553264065            0.00            0.00        1
# 3                  0.00    C38997010        21182.00            0.00        1
# 4              29885.86  M1230701703            0.00            0.00        0
# ...                 ...          ...             ...             ...      ...
# 6362615            0.00   C776919290            0.00       339682.13        1
# 6362616            0.00  C1881841831            0.00            0.00        1
# 6362617            0.00  C1365125890        68488.84      6379898.11        1
# 6362618            0.00  C2080388513            0.00            0.00        1
# 6362619            0.00   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 6362615               0
# 6362616               0
# 6362617               0
# 6362618               0
# 6362619               0
#
# [6362620 rows x 11 columns]

# %% [markdown]
# Online Payments Fraud Detection Dataset
# Online payment fraud big dataset for testing and practice purpose
#
# 1, Step: Represents a unit of time where 1 step equals 1 hour
# 2, Type: Type of online transaction
# 3, Amount: The amount of the transaction
# 4, NameOrig: Customer starting the transaction
# 5, OldbalanceOrg: Balance before the transaction
# 6, NewbalanceOrig: Balance after the transaction
# 7, NameDest: Recipient of the transaction
# 8, OldbalanceDest: Initial balance of recipient before the transaction
# 9, NewbalanceDest: The new balance of recipient after the transaction
# 10,IsFraud: Fraud transaction

# %%
import matplotlib.pyplot as plt
import seaborn

# %%
print(df.isnull().sum())
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB
# None

# %% [markdown]
# Dataset is clean

# %%
print(df['step'].value_counts())
# Out:
# step
# 19     51352
# 18     49579
# 187    49083
# 235    47491
# 307    46968
#        ...
# 432        4
# 706        4
# 693        4
# 112        2
# 662        2
# Name: count, Length: 743, dtype: int64

# %%
print(df['type'].value_counts())
# Out:
# type
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: count, dtype: int64

# %%
print(df['nameOrig'])
# Out:
# 0          C1231006815
# 1          C1666544295
# 2          C1305486145
# 3           C840083671
# 4          C2048537720
#               ...
# 6362615     C786484425
# 6362616    C1529008245
# 6362617    C1162922333
# 6362618    C1685995037
# 6362619    C1280323807
# Name: nameOrig, Length: 6362620, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
encode=LabelEncoder()
df["type"]=encode.fit_transform(df["type"])
df
# Out:
#          step  type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1     3     9839.64  C1231006815      170136.00       160296.36
# 1           1     3     1864.28  C1666544295       21249.00        19384.72
# 2           1     4      181.00  C1305486145         181.00            0.00
# 3           1     1      181.00   C840083671         181.00            0.00
# 4           1     3    11668.14  C2048537720       41554.00        29885.86
# ...       ...   ...         ...          ...            ...             ...
# 6362615   743     1   339682.13   C786484425      339682.13            0.00
# 6362616   743     4  6311409.28  C1529008245     6311409.28            0.00
# 6362617   743     1  6311409.28  C1162922333     6311409.28            0.00
# 6362618   743     4   850002.52  C1685995037      850002.52            0.00
# 6362619   743     1   850002.52  C1280323807      850002.52            0.00
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0        M1979787155            0.00            0.00        0               0
# 1        M2044282225            0.00            0.00        0               0
# 2         C553264065            0.00            0.00        1               0
# 3          C38997010        21182.00            0.00        1               0
# 4        M1230701703            0.00            0.00        0               0
# ...              ...             ...             ...      ...             ...
# 6362615   C776919290            0.00       339682.13        1               0
# 6362616  C1881841831            0.00            0.00        1               0
# 6362617  C1365125890        68488.84      6379898.11        1               0
# 6362618  C2080388513            0.00            0.00        1               0
# 6362619   C873221189      6510099.11      7360101.63        1               0
#
# [6362620 rows x 11 columns]

# %%
df.drop(['nameOrig', 'nameDest'], axis=1, inplace=True)

# %%
plt.figure(figsize=(7,5))
plt.hist(df["type"],color="coral",edgecolor="black")
plt.title("Types of Payment")
plt.xlabel("Amount")
plt.ylabel("Payment Mode")
plt.grid(True)
Plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 7
#       5 plt.ylabel("Payment Mode")
#       6 plt.grid(True)
# ----> 7 Plt.show()
#
# NameError: name 'Plt' is not defined

# %%
print(df['amount'].value_counts())
# Out:
# amount
# 10000000.00    3207
# 10000.00         88
# 5000.00          79
# 15000.00         68
# 500.00           65
#                ...
# 8513.48           1
# 189137.90         1
# 1615.78           1
# 128891.19         1
# 12257.89          1
# Name: count, Length: 5316900, dtype: int64

# %%
print(df['oldbalanceOrg'].value_counts())
# Out:
# oldbalanceOrg
# 0.00         2102449
# 184.00           918
# 133.00           914
# 195.00           912
# 164.00           909
#               ...
# 34577.49           1
# 184929.21          1
# 29320.33           1
# 82645.19           1
# 641239.85          1
# Name: count, Length: 1845844, dtype: int64

# %%
print(df['newbalanceOrig'].value_counts())
# Out:
# newbalanceOrig
# 0.00         3609566
# 5888.64            4
# 15073.44           4
# 5122.00            4
# 36875.73           4
#               ...
# 51345.64           1
# 46527.23           1
# 30839.51           1
# 25521.75           1
# 160296.36          1
# Name: count, Length: 2682586, dtype: int64

# %%
print(df['oldbalanceDest'].value_counts())
# Out:
# oldbalanceDest
# 0.00           2704388
# 10000000.00        615
# 20000000.00        219
# 30000000.00         86
# 40000000.00         31
#                 ...
# 967022.27            1
# 327279.67            1
# 2039554.04           1
# 587552.25            1
# 6510099.11           1
# Name: count, Length: 3614697, dtype: int64

# %%
print(df['newbalanceDest'].value_counts())
# Out:
# newbalanceDest
# 0.00           2439433
# 10000000.00         53
# 971418.91           32
# 19169204.93         29
# 1254956.07          25
#                 ...
# 188439.36            1
# 1347758.15           1
# 3878719.83           1
# 1605826.83           1
# 7360101.63           1
# Name: count, Length: 3555499, dtype: int64

# %%
x=df.iloc[:, :-1]
y=df.iloc[0:,-1]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=scaler.fit_transform(x)
x
# Out:
# array([[-1.70304158,  0.95239932, -0.28155992, ..., -0.3238139 ,
#         -0.33341141, -0.0359512 ],
#        [-1.70304158,  0.95239932, -0.29476726, ..., -0.3238139 ,
#         -0.33341141, -0.0359512 ],
#        [-1.70304158,  1.69307616, -0.2975548 , ..., -0.3238139 ,
#         -0.33341141, 27.8154828 ],
#        ...,
#        [ 3.51012348, -0.52895436, 10.1539526 , ..., -0.30366526,
#          1.403027  , 27.8154828 ],
#        [ 3.51012348,  1.69307616,  1.1097649 , ..., -0.3238139 ,
#         -0.33341141, 27.8154828 ],
#        [ 3.51012348, -0.52895436,  1.1097649 , ...,  1.59138312,
#          1.6698123 , 27.8154828 ]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[-0.59998644, -0.52895436, -0.13227472, ..., -0.05491812,
#         -0.05742438, -0.0359512 ],
#        [-0.06602344, -0.52895436, -0.1945097 , ..., -0.18656739,
#         -0.18945042, -0.0359512 ],
#        [-1.6117058 ,  1.69307616,  3.49673354, ...,  0.77333192,
#          1.30528706, -0.0359512 ],
#        ...,
#        [-0.40326323, -1.2696312 , -0.16563721, ..., -0.2425661 ,
#         -0.27997415, -0.0359512 ],
#        [-0.71942553, -1.2696312 ,  0.64376472, ...,  0.45043066,
#          0.22813452, -0.0359512 ],
#        [ 0.57332699, -1.2696312 , -0.0531246 , ..., -0.19033326,
#         -0.250142  , -0.0359512 ]])

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=classifier.predict(x_test) # Prediction
print(y_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
y_test # actual
# Out:
# 4644207    0
# 3800666    0
# 4426240    0
# 5788765    0
# 2010701    0
#           ..
# 3408852    0
# 2756286    0
# 3167668    0
# 3337309    0
# 4993651    0
# Name: isFlaggedFraud, Length: 1272524, dtype: int64

# %% [markdown]
# ACCURACY SCORE

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9999952849612267

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier=DecisionTreeClassifier(max_depth=5)
classifier.fit(x_train,y_train)

# %%
y_pred=classifier.predict(x_test)

# %% [markdown]
# Here am checking accuracy ,Precision,Recall,F1 Score & Confusion Matrix

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Optional: full report
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# %%
print(y_pred[:10])

# %%
from sklearn.metrics import precision_recall_curve
import numpy as np

precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred)
f1_scores = 2 * (precisions * recalls) / (precisions + recalls)
best_idx = np.argmax(f1_scores)

best_threshold = thresholds[best_idx]
print("Best threshold for F1:", best_threshold)
print("Best F1 score:", f1_scores[best_idx])

# Apply the new threshold
y_pred_labels = (y_pred >= best_threshold).astype(int)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
